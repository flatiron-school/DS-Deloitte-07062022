# %%
import pandas as pd

# %%
all_cases = pd.read_csv('./raw data/cv88on.txt',
                        delimiter = "\t",
                        encoding="latin1",
                        low_memory=False)

# %%
all_cases
# Out:
#          CIRCUIT DISTRICT OFFICE   DOCKET  ORIGIN    FILEDATE    FDATEUSE  \
# 0              0       90      1  7101462       4  07/21/1971  07/01/1971
# 1              0       90      1  7300974       4  05/17/1973  02/01/1983
# 2              0       90      1  7601326       4  01/31/1985  06/01/1985
# 3              0       90      1  7700081       3  09/19/1984  05/01/1986
# 4              0       90      1  7901559       2  06/15/1979  06/01/1979
# ...          ...      ...    ...      ...     ...         ...         ...
# 9676637       11       3J      6  2200045       1  06/14/2022  06/01/2022
# 9676638       11       3J      6  2200046       1  06/16/2022  06/01/2022
# 9676639       11       3J      6  2200047       1  06/21/2022  06/01/2022
# 9676640       11       3J      6  2200048       1  06/21/2022  06/01/2022
# 9676641       11       3J      6  2200049       1  06/21/2022  06/01/2022
#
#          JURIS  NOS TITL  ... JUDGMENT     DJOINED  PRETRIAL TRIBEGAN  \
# ...
